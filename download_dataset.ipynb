# %%
# cella per check di roboflow


import sys
print(sys.executable)
# !{sys.executable} -m pip install supervision
from roboflow import Roboflow
print("OK")
# Out:
# c:\Users\marra\anaconda3\envs\IS_AY2526\python.exe
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# roboflow 1.1.9 requires chardet==4.0.0, which is not installed.
# roboflow 1.1.9 requires python-magic, which is not installed.
# roboflow 1.1.9 requires certifi==2023.7.22, but you have certifi 2024.8.30 which is incompatible.
# roboflow 1.1.9 requires cycler==0.10.0, but you have cycler 0.11.0 which is incompatible.
# roboflow 1.1.9 requires idna==2.10, but you have idna 3.7 which is incompatible.
# roboflow 1.1.9 requires opencv-python-headless==4.8.0.74, but you have opencv-python-headless 4.10.0.84 which is incompatible.
# roboflow 1.1.9 requires pyparsing==2.4.7, but you have pyparsing 3.0.9 which is incompatible.
# Collecting supervision
#   Using cached supervision-0.25.1-py3-none-any.whl.metadata (14 kB)
# Collecting contourpy>=1.0.7 (from supervision)
#   Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib<3.8.0,>=3.6.0 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (3.7.2)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (1.24.3)
# Collecting opencv-python>=4.5.5.64 (from supervision)
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=9.4 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy==1.10.0 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (1.10.0)
# Requirement already satisfied: tqdm>=4.62.3 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from supervision) (4.67.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from matplotlib<3.8.0,>=3.6.0->supervision) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from matplotlib<3.8.0,>=3.6.0->supervision) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from matplotlib<3.8.0,>=3.6.0->supervision) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from matplotlib<3.8.0,>=3.6.0->supervision) (24.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from matplotlib<3.8.0,>=3.6.0->supervision) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from matplotlib<3.8.0,>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from matplotlib<3.8.0,>=3.6.0->supervision) (6.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from requests>=2.26.0->supervision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from requests>=2.26.0->supervision) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from requests>=2.26.0->supervision) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from requests>=2.26.0->supervision) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from tqdm>=4.62.3->supervision) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from importlib-resources>=3.2.0->matplotlib<3.8.0,>=3.6.0->supervision) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\marra\anaconda3\envs\is_ay2526\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0,>=3.6.0->supervision) (1.16.0)
# Using cached supervision-0.25.1-py3-none-any.whl (181 kB)
# Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# Installing collected packages: opencv-python, contourpy, supervision
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.0.5
#     Uninstalling contourpy-1.0.5:
#       Successfully uninstalled contourpy-1.0.5
# Successfully installed contourpy-1.1.1 opencv-python-4.13.0.92 supervision-0.25.1
# OK

# %%
#cella per download dataset


from roboflow import Roboflow

rf = Roboflow(api_key="vBDzTXMtTJ5OpeGMeWom")
project = rf.workspace("ben-gann-lscqy").project("pool-balls-qlnkb")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Pool-Balls-1 to yolov5pytorch:: 100%|██████████| 136053/136053 [00:36<00:00, 3680.84it/s]
# Extracting Dataset Version Zip to Pool-Balls-1 in yolov5pytorch:: 100%|██████████| 18298/18298 [00:19<00:00, 926.28it/s]
