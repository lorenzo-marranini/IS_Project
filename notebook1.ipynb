# %%
# to install 8 ball pool dataset with all balls and holes as classes
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vBDzTXMtTJ5OpeGMeWom")
project = rf.workspace("ben-gann-lscqy").project("pool-balls-qlnkb")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
#   error: subprocess-exited-with-error
#
#   × Building wheel for pillow-avif-plugin (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [9 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\pillow_avif
#       copying src\pillow_avif\AvifImagePlugin.py -> build\lib.win-amd64-cpython-38\pillow_avif
#       copying src\pillow_avif\__init__.py -> build\lib.win-amd64-cpython-38\pillow_avif
#       running build_ext
#       building 'pillow_avif._avif' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pillow-avif-plugin
# ...
